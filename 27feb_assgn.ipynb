# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [raw]
# A python supported library that facilitates plotting of functions on 2D or 3D planes is known as matplotlib.
# Five plots that can be plotted using matplotlib :
#     Scatter Plot
#     Grid Plot
#     Bar Graph
#     Histogram
#     3D Plot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %%
import matplotlib.pyplot as plt
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])
y1 = np.array([50, 20, 40, 20, 60, 70])
y2 = np.array([10, 20, 30, 40, 50, 60])
y3  = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2,2,1)
plt.plot(x,y)
plt.show

plt.subplot(2,2,2)
plt.plot(x,y1)
plt.show

plt.subplot(2,2,3)
plt.plot(x,y2)
plt.show

plt.subplot(2,2,4)
plt.plot(x,y3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [raw]
# Ans. The plot which is used for a visulisation of categorical data in the form of rectangular bars.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.subplot(2,1,1)
plt.bar(company,profit)
plt.subplot(2,1,2)
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [raw]
# THe box plot is the graphical representation of the spread of dispersion if data.
# It provides a visual summary of data's central tendency,spread and potential outliners.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.subplot(2,1,1)
plt.boxplot(box1)
plt.show()
plt.subplot(2,1,2)
plt.boxplot(box2)
plt.show()
